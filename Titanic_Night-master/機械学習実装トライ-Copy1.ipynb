# %%
#https://qiita.com/upura/items/3c10ff6fed4e7c3d70f0
#とりあえず日本語での記事から学習して見とうと思い、qiitaの簡単そうな記事からトライしようと思いました。

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('https://raw.githubusercontent.com/dominono9/pythonstudy/master/Titanic_Night-master/data/train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/dominono9/pythonstudy/master/Titanic_Night-master/data/test.csv')
gender_submission = pd.read_csv('https://raw.githubusercontent.com/dominono9/pythonstudy/master/Titanic_Night-master/data/gender_submission.csv')

# %%
from sklearn.linear_model import LogisticRegression

#1分類器を設定
clf = LogisticRegression(penalty='l2', solver='sag', random_state=0)
#2学習させる
#↓を実行するとエラーになってしまう。
#clf.fit(X_train, y_train)

# %%
#clfの中身をとりあえず見てみる。
clf
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='sag', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#3予測させる
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1107339937d2> in <module>
#       1 #3予測させる
# ----> 2 y_pred = clf.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
#csvを出力させる
sub = pd.DataFrame(pd.read_csv('../input/titanic/test.csv')['PassengerId'])
sub['Survived'] = list(map(int, y_pred))
sub.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6ad9124595ae> in <module>
#       1 #csvを出力させる
# ----> 2 sub = pd.DataFrame(pd.read_csv('../input/titanic/test.csv')['PassengerId'])
#       3 sub['Survived'] = list(map(int, y_pred))
#       4 sub.to_csv('submission.csv', index=False)
#
# ...

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
